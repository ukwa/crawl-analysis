# %% [markdown]
# 2015 Domain Crawl Analysis
# ==============
#
# This notebook analyses the 2015 domain crawl, based on a transformed version of the crawl log.
#
# We parsed the `crawl.log` to a series of JSON-formatted entries like:
#
#     {
#         "ip": {
#             "72.52.4.119": 2
#         },
#         "tld": "uk",
#         "virus": {},
#         "host": "eastcoastribs.co.uk",
#         "mime": {
#             "text/html": 1,
#             "text/plain": 1
#         },
#         "2ld": "co"
#     }
#
# A sample of which is in the file `2014-crawl-log-sample.json`. The full output resides in HDFS and we use the `python-webhdfs` library to read this in.
#
# **NOTE**: the below pulls the entire dataset from HDFS; if you want to quickly test, use the commented code that reads in `2014-crawl-log-sample.json`.
#
# Wish List
# ----------
#
# * **% .uk domain and non-uk**
# * **Type of second level domain – so what %  .co.uk, .org.uk , .ac.uk etc    (and the same info if available for non-UK domain sites  .com, .org etc)**
# * Main language of website: English vs other
# * Institution/commercial vs individual / personal
# * **Location – geographical spread across UK (by country, region, north-south)    (where are most heavily represented regions / cities, where are the lowest) – and maybe based on mapping to income levels % in more wealthy areas vs % in low-income areas.**
# * If possible, map locations to cities and towns to calculate % urban vs rural.
# * Type of content: % mainly textual,  % of sites with audio / visual content
# * % freely available/open access vs % subscription / paywall protected
# * Frequency of updates:  % of sites updated daily or more vs fairly static
# * **Compared to previous year’s crawl: % still active/live  (there in 2014, still there in 2015), % new  (not there in 2014, there in 2015) , % defunct/disappeared (ie. there in 2014 but gone in 2015)**
# * Size: % 100 pages or more vs % less than 100 pages  (or whatever number is most meaningful)   (flat vs deep)
# * **Largest sites in terms of no. of pages.  (or other measure of size if appropriate)**
# * What percentage of UK webspace is occupied by largest sites vs percentage occupied by small sites    (idea would be something similar to a breakdown of wealth eg. top 10% own 45% of GDP, poorest 10% own 2% of GDP.)
# * Most linked to; location of links – eg. % with primarily UK links, % with primarily international links
# * Countries most linked outside UK domain  (and by region US, Europe, Asia…)
# * **Year on year change in number of sites, size of sites or any of the above.**
# * Target audience by age range:   all /adults,   youth,   children,  older people.   (any other social demographics that can be gleaned – ethnicity?)
# * File types – sound,  video,  pdfs.
#
# Built with help from
# ----------------------
#
# * <http://introtopython.org/visualization_earthquakes.html>
# * <http://web.stanford.edu/~mwaskom/software/seaborn/>

# %% [markdown]
# Loading the data
# ------------------

# %%
import logging
import json
import webhdfs
import geoip2.database
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib.cm as cm
import numpy as np
import string
import pandas as pd
import seaborn
from collections import Counter
from collections import OrderedDict
from geoip2.errors import AddressNotFoundError
from mpl_toolkits.basemap import Basemap 
# %matplotlib inline

logger = logging.getLogger("webhdfs")
logger.setLevel(logging.INFO)

tlds = Counter()
slds = Counter()
lat_lon = []
host_sizes = {}

def loader(source):
    reader = geoip2.database.Reader("GeoLite2-City.mmdb")
    lines = 0
    for line in source:
        host = json.loads(line)
        tlds.update([host["tld"]])
        if "2ld" in host.keys():
            slds.update([host["2ld"]])
        lines = lines + 1
        #if host["tld"] == "uk":
        for ip in host["ip"].keys():
            try:
                response = reader.city(ip)
                lat_lon.append((response.location.latitude, response.location.longitude))
            except AddressNotFoundError:
                pass
        host_sizes[host["host"]] = sum(host["mime"].values())
        if lines % 10000 == 0:
            print("Processed %i lines (i.e. hosts) so far..." % lines)
    reader.close()
    print("Loaded data from %i lines/hosts." % lines)

print("Loading...")
    
# Load the test data:
#with open("2014-crawl-log-sample.json", "r") as i:
#    loader(i)

# Load the full crawl data:
w = webhdfs.API(prefix="http://194.66.232.90:14000/webhdfs/v1", user="heritrix")
loader(w.readlines("/user/anjackson/crawl-log-2015-out/", decompress=True))

print("Loaded.")
# Out:
# /usr/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# INFO:webhdfs.webhdfs:Examining path /user/anjackson/crawl-log-2015-out/
# Loading...
# Processed 10000 lines (i.e. hosts) so far...
# Processed 20000 lines (i.e. hosts) so far...
# Processed 30000 lines (i.e. hosts) so far...
# Processed 40000 lines (i.e. hosts) so far...
# Processed 50000 lines (i.e. hosts) so far...
# Processed 60000 lines (i.e. hosts) so far...
# Processed 70000 lines (i.e. hosts) so far...
# Processed 80000 lines (i.e. hosts) so far...
# Processed 90000 lines (i.e. hosts) so far...
# Processed 100000 lines (i.e. hosts) so far...
# Processed 110000 lines (i.e. hosts) so far...
# Processed 120000 lines (i.e. hosts) so far...
# Processed 130000 lines (i.e. hosts) so far...
# Processed 140000 lines (i.e. hosts) so far...
# Processed 150000 lines (i.e. hosts) so far...
# Processed 160000 lines (i.e. hosts) so far...
# Processed 170000 lines (i.e. hosts) so far...
# Processed 180000 lines (i.e. hosts) so far...
# Processed 190000 lines (i.e. hosts) so far...
# Processed 200000 lines (i.e. hosts) so far...
# Processed 210000 lines (i.e. hosts) so far...
# Processed 220000 lines (i.e. hosts) so far...
# Processed 230000 lines (i.e. hosts) so far...
# Processed 240000 lines (i.e. hosts) so far...
# Processed 250000 lines (i.e. hosts) so far...
# Processed 260000 lines (i.e. hosts) so far...
# Processed 270000 lines (i.e. hosts) so far...
# Processed 280000 lines (i.e. hosts) so far...
# Processed 290000 lines (i.e. hosts) so far...
# Processed 300000 lines (i.e. hosts) so far...
# Processed 310000 lines (i.e. hosts) so far...
# Processed 320000 lines (i.e. hosts) so far...
# Processed 330000 lines (i.e. hosts) so far...
# Processed 340000 lines (i.e. hosts) so far...
# Processed 350000 lines (i.e. hosts) so far...
# Processed 360000 lines (i.e. hosts) so far...
# Processed 370000 lines (i.e. hosts) so far...
# Processed 380000 lines (i.e. hosts) so far...
# Processed 390000 lines (i.e. hosts) so far...
# Processed 400000 lines (i.e. hosts) so far...
# Processed 410000 lines (i.e. hosts) so far...
# Processed 420000 lines (i.e. hosts) so far...
# Processed 430000 lines (i.e. hosts) so far...
# Processed 440000 lines (i.e. hosts) so far...
# Processed 450000 lines (i.e. hosts) so far...
# Processed 460000 lines (i.e. hosts) so far...
# Processed 470000 lines (i.e. hosts) so far...
# Processed 480000 lines (i.e. hosts) so far...
# Processed 490000 lines (i.e. hosts) so far...
# Processed 500000 lines (i.e. hosts) so far...
# Processed 510000 lines (i.e. hosts) so far...
# Processed 520000 lines (i.e. hosts) so far...
# Processed 530000 lines (i.e. hosts) so far...
# Processed 540000 lines (i.e. hosts) so far...
# Processed 550000 lines (i.e. hosts) so far...
# Processed 560000 lines (i.e. hosts) so far...
# Processed 570000 lines (i.e. hosts) so far...
# Processed 580000 lines (i.e. hosts) so far...
# Processed 590000 lines (i.e. hosts) so far...
# Processed 600000 lines (i.e. hosts) so far...
# Processed 610000 lines (i.e. hosts) so far...
# Processed 620000 lines (i.e. hosts) so far...
# Processed 630000 lines (i.e. hosts) so far...
# Processed 640000 lines (i.e. hosts) so far...
# Processed 650000 lines (i.e. hosts) so far...
# Processed 660000 lines (i.e. hosts) so far...
# Processed 670000 lines (i.e. hosts) so far...
# Processed 680000 lines (i.e. hosts) so far...
# Processed 690000 lines (i.e. hosts) so far...
# Processed 700000 lines (i.e. hosts) so far...
# Processed 710000 lines (i.e. hosts) so far...
# Processed 720000 lines (i.e. hosts) so far...
# Processed 730000 lines (i.e. hosts) so far...
# Processed 740000 lines (i.e. hosts) so far...
# Processed 750000 lines (i.e. hosts) so far...
# Processed 760000 lines (i.e. hosts) so far...
# Processed 770000 lines (i.e. hosts) so far...
# Processed 780000 lines (i.e. hosts) so far...
# Processed 790000 lines (i.e. hosts) so far...
# Processed 800000 lines (i.e. hosts) so far...
# Processed 810000 lines (i.e. hosts) so far...
# Processed 820000 lines (i.e. hosts) so far...
# Processed 830000 lines (i.e. hosts) so far...
# Processed 840000 lines (i.e. hosts) so far...
# Processed 850000 lines (i.e. hosts) so far...
# Processed 860000 lines (i.e. hosts) so far...
# Processed 870000 lines (i.e. hosts) so far...
# Processed 880000 lines (i.e. hosts) so far...
# Processed 890000 lines (i.e. hosts) so far...
# Processed 900000 lines (i.e. hosts) so far...
# Processed 910000 lines (i.e. hosts) so far...
# Processed 920000 lines (i.e. hosts) so far...
# Processed 930000 lines (i.e. hosts) so far...
# Processed 940000 lines (i.e. hosts) so far...
# Processed 950000 lines (i.e. hosts) so far...
# Processed 960000 lines (i.e. hosts) so far...
# Processed 970000 lines (i.e. hosts) so far...
# Processed 980000 lines (i.e. hosts) so far...
# Processed 990000 lines (i.e. hosts) so far...
# Processed 1000000 lines (i.e. hosts) so far...
# Processed 1010000 lines (i.e. hosts) so far...
# Processed 1020000 lines (i.e. hosts) so far...
# Processed 1030000 lines (i.e. hosts) so far...
# Processed 1040000 lines (i.e. hosts) so far...
# Processed 1050000 lines (i.e. hosts) so far...
# Processed 1060000 lines (i.e. hosts) so far...
# Processed 1070000 lines (i.e. hosts) so far...
# Processed 1080000 lines (i.e. hosts) so far...
# Processed 1090000 lines (i.e. hosts) so far...
# Processed 1100000 lines (i.e. hosts) so far...
# Processed 1110000 lines (i.e. hosts) so far...
# Processed 1120000 lines (i.e. hosts) so far...
# Processed 1130000 lines (i.e. hosts) so far...
# Processed 1140000 lines (i.e. hosts) so far...
# Processed 1150000 lines (i.e. hosts) so far...
# Processed 1160000 lines (i.e. hosts) so far...
# Processed 1170000 lines (i.e. hosts) so far...
# Processed 1180000 lines (i.e. hosts) so far...
# Processed 1190000 lines (i.e. hosts) so far...
# Processed 1200000 lines (i.e. hosts) so far...
# Processed 1210000 lines (i.e. hosts) so far...
# Processed 1220000 lines (i.e. hosts) so far...
# Processed 1230000 lines (i.e. hosts) so far...
# Processed 1240000 lines (i.e. hosts) so far...
# Processed 1250000 lines (i.e. hosts) so far...
# Processed 1260000 lines (i.e. hosts) so far...
# Processed 1270000 lines (i.e. hosts) so far...
# Processed 1280000 lines (i.e. hosts) so far...
# Processed 1290000 lines (i.e. hosts) so far...
# Processed 1300000 lines (i.e. hosts) so far...
# Processed 1310000 lines (i.e. hosts) so far...
# Processed 1320000 lines (i.e. hosts) so far...
# Processed 1330000 lines (i.e. hosts) so far...
# Processed 1340000 lines (i.e. hosts) so far...
# Processed 1350000 lines (i.e. hosts) so far...
# Processed 1360000 lines (i.e. hosts) so far...
# Processed 1370000 lines (i.e. hosts) so far...
# Processed 1380000 lines (i.e. hosts) so far...
# Processed 1390000 lines (i.e. hosts) so far...
# Processed 1400000 lines (i.e. hosts) so far...
# Processed 1410000 lines (i.e. hosts) so far...
# Processed 1420000 lines (i.e. hosts) so far...
# Processed 1430000 lines (i.e. hosts) so far...
# Processed 1440000 lines (i.e. hosts) so far...
# Processed 1450000 lines (i.e. hosts) so far...
# Processed 1460000 lines (i.e. hosts) so far...
# Processed 1470000 lines (i.e. hosts) so far...
# Processed 1480000 lines (i.e. hosts) so far...
# Processed 1490000 lines (i.e. hosts) so far...
# Processed 1500000 lines (i.e. hosts) so far...
# Processed 1510000 lines (i.e. hosts) so far...
# Processed 1520000 lines (i.e. hosts) so far...
# Processed 1530000 lines (i.e. hosts) so far...
# Processed 1540000 lines (i.e. hosts) so far...
# Processed 1550000 lines (i.e. hosts) so far...
# Processed 1560000 lines (i.e. hosts) so far...
# Processed 1570000 lines (i.e. hosts) so far...
# Processed 1580000 lines (i.e. hosts) so far...
# Processed 1590000 lines (i.e. hosts) so far...
# Processed 1600000 lines (i.e. hosts) so far...
# Processed 1610000 lines (i.e. hosts) so far...
# Processed 1620000 lines (i.e. hosts) so far...
# Processed 1630000 lines (i.e. hosts) so far...
# Processed 1640000 lines (i.e. hosts) so far...
# Processed 1650000 lines (i.e. hosts) so far...
# Processed 1660000 lines (i.e. hosts) so far...
# Processed 1670000 lines (i.e. hosts) so far...
# Processed 1680000 lines (i.e. hosts) so far...
# Processed 1690000 lines (i.e. hosts) so far...
# Processed 1700000 lines (i.e. hosts) so far...
# Processed 1710000 lines (i.e. hosts) so far...
# Processed 1720000 lines (i.e. hosts) so far...
# Processed 1730000 lines (i.e. hosts) so far...
# Processed 1740000 lines (i.e. hosts) so far...
# Processed 1750000 lines (i.e. hosts) so far...
# Processed 1760000 lines (i.e. hosts) so far...
# Processed 1770000 lines (i.e. hosts) so far...
# Processed 1780000 lines (i.e. hosts) so far...
# Processed 1790000 lines (i.e. hosts) so far...
# Processed 1800000 lines (i.e. hosts) so far...
# Processed 1810000 lines (i.e. hosts) so far...
# Processed 1820000 lines (i.e. hosts) so far...
# Processed 1830000 lines (i.e. hosts) so far...
# Processed 1840000 lines (i.e. hosts) so far...
# Processed 1850000 lines (i.e. hosts) so far...
# Processed 1860000 lines (i.e. hosts) so far...
# Processed 1870000 lines (i.e. hosts) so far...
# Processed 1880000 lines (i.e. hosts) so far...
# Processed 1890000 lines (i.e. hosts) so far...
# Processed 1900000 lines (i.e. hosts) so far...
# Processed 1910000 lines (i.e. hosts) so far...
# Processed 1920000 lines (i.e. hosts) so far...
# Processed 1930000 lines (i.e. hosts) so far...
# Processed 1940000 lines (i.e. hosts) so far...
# Processed 1950000 lines (i.e. hosts) so far...
# Processed 1960000 lines (i.e. hosts) so far...
# Processed 1970000 lines (i.e. hosts) so far...
# Processed 1980000 lines (i.e. hosts) so far...
# Processed 1990000 lines (i.e. hosts) so far...
# Processed 2000000 lines (i.e. hosts) so far...
# Processed 2010000 lines (i.e. hosts) so far...
# Processed 2020000 lines (i.e. hosts) so far...
# Processed 2030000 lines (i.e. hosts) so far...
# Processed 2040000 lines (i.e. hosts) so far...
# Processed 2050000 lines (i.e. hosts) so far...
# Processed 2060000 lines (i.e. hosts) so far...
# Processed 2070000 lines (i.e. hosts) so far...
# Processed 2080000 lines (i.e. hosts) so far...
# Processed 2090000 lines (i.e. hosts) so far...
# Processed 2100000 lines (i.e. hosts) so far...
# Processed 2110000 lines (i.e. hosts) so far...
# Processed 2120000 lines (i.e. hosts) so far...
# Processed 2130000 lines (i.e. hosts) so far...
# Processed 2140000 lines (i.e. hosts) so far...
# Processed 2150000 lines (i.e. hosts) so far...
# Processed 2160000 lines (i.e. hosts) so far...
# Processed 2170000 lines (i.e. hosts) so far...
# Processed 2180000 lines (i.e. hosts) so far...
# Processed 2190000 lines (i.e. hosts) so far...
# Processed 2200000 lines (i.e. hosts) so far...
# Processed 2210000 lines (i.e. hosts) so far...
# Processed 2220000 lines (i.e. hosts) so far...
# Processed 2230000 lines (i.e. hosts) so far...
# Processed 2240000 lines (i.e. hosts) so far...
# Processed 2250000 lines (i.e. hosts) so far...
# Processed 2260000 lines (i.e. hosts) so far...
# Processed 2270000 lines (i.e. hosts) so far...
# Processed 2280000 lines (i.e. hosts) so far...
# Processed 2290000 lines (i.e. hosts) so far...
# Processed 2300000 lines (i.e. hosts) so far...
# Processed 2310000 lines (i.e. hosts) so far...
# Processed 2320000 lines (i.e. hosts) so far...
# Processed 2330000 lines (i.e. hosts) so far...
# Processed 2340000 lines (i.e. hosts) so far...
# Processed 2350000 lines (i.e. hosts) so far...
# Processed 2360000 lines (i.e. hosts) so far...
# Processed 2370000 lines (i.e. hosts) so far...
# Processed 2380000 lines (i.e. hosts) so far...
# Processed 2390000 lines (i.e. hosts) so far...
# Processed 2400000 lines (i.e. hosts) so far...
# Processed 2410000 lines (i.e. hosts) so far...
# Processed 2420000 lines (i.e. hosts) so far...
# Processed 2430000 lines (i.e. hosts) so far...
# Processed 2440000 lines (i.e. hosts) so far...
# Processed 2450000 lines (i.e. hosts) so far...
# Processed 2460000 lines (i.e. hosts) so far...
# Processed 2470000 lines (i.e. hosts) so far...
# Processed 2480000 lines (i.e. hosts) so far...
# Processed 2490000 lines (i.e. hosts) so far...
# Processed 2500000 lines (i.e. hosts) so far...
# Processed 2510000 lines (i.e. hosts) so far...
# Processed 2520000 lines (i.e. hosts) so far...
# Processed 2530000 lines (i.e. hosts) so far...
# Processed 2540000 lines (i.e. hosts) so far...
# Processed 2550000 lines (i.e. hosts) so far...
# Processed 2560000 lines (i.e. hosts) so far...
# Processed 2570000 lines (i.e. hosts) so far...
# Processed 2580000 lines (i.e. hosts) so far...
# Processed 2590000 lines (i.e. hosts) so far...
# Processed 2600000 lines (i.e. hosts) so far...
# Processed 2610000 lines (i.e. hosts) so far...
# Processed 2620000 lines (i.e. hosts) so far...
# Processed 2630000 lines (i.e. hosts) so far...
# Processed 2640000 lines (i.e. hosts) so far...
# Processed 2650000 lines (i.e. hosts) so far...
# Processed 2660000 lines (i.e. hosts) so far...
# Processed 2670000 lines (i.e. hosts) so far...
# Processed 2680000 lines (i.e. hosts) so far...
# Processed 2690000 lines (i.e. hosts) so far...
# Processed 2700000 lines (i.e. hosts) so far...
# Processed 2710000 lines (i.e. hosts) so far...
# Processed 2720000 lines (i.e. hosts) so far...
# Processed 2730000 lines (i.e. hosts) so far...
# Processed 2740000 lines (i.e. hosts) so far...
# Processed 2750000 lines (i.e. hosts) so far...
# Processed 2760000 lines (i.e. hosts) so far...
# Processed 2770000 lines (i.e. hosts) so far...
# Processed 2780000 lines (i.e. hosts) so far...
# Processed 2790000 lines (i.e. hosts) so far...
# Processed 2800000 lines (i.e. hosts) so far...
# Processed 2810000 lines (i.e. hosts) so far...
# Processed 2820000 lines (i.e. hosts) so far...
# Processed 2830000 lines (i.e. hosts) so far...
# Processed 2840000 lines (i.e. hosts) so far...
# Processed 2850000 lines (i.e. hosts) so far...
# Processed 2860000 lines (i.e. hosts) so far...
# Processed 2870000 lines (i.e. hosts) so far...
# Processed 2880000 lines (i.e. hosts) so far...
# Processed 2890000 lines (i.e. hosts) so far...
# Processed 2900000 lines (i.e. hosts) so far...
# Processed 2910000 lines (i.e. hosts) so far...
# Processed 2920000 lines (i.e. hosts) so far...
# Processed 2930000 lines (i.e. hosts) so far...
# Processed 2940000 lines (i.e. hosts) so far...
# Processed 2950000 lines (i.e. hosts) so far...
# Processed 2960000 lines (i.e. hosts) so far...
# Processed 2970000 lines (i.e. hosts) so far...
# Processed 2980000 lines (i.e. hosts) so far...
# Processed 2990000 lines (i.e. hosts) so far...
# Processed 3000000 lines (i.e. hosts) so far...
# Processed 3010000 lines (i.e. hosts) so far...
# Processed 3020000 lines (i.e. hosts) so far...
# Processed 3030000 lines (i.e. hosts) so far...
# Processed 3040000 lines (i.e. hosts) so far...
# Processed 3050000 lines (i.e. hosts) so far...
# Processed 3060000 lines (i.e. hosts) so far...
# Processed 3070000 lines (i.e. hosts) so far...
# Processed 3080000 lines (i.e. hosts) so far...
# Processed 3090000 lines (i.e. hosts) so far...
# Processed 3100000 lines (i.e. hosts) so far...
# Processed 3110000 lines (i.e. hosts) so far...
# Processed 3120000 lines (i.e. hosts) so far...
# Processed 3130000 lines (i.e. hosts) so far...
# Processed 3140000 lines (i.e. hosts) so far...
# Processed 3150000 lines (i.e. hosts) so far...
# Processed 3160000 lines (i.e. hosts) so far...
# Processed 3170000 lines (i.e. hosts) so far...
# Processed 3180000 lines (i.e. hosts) so far...
# Processed 3190000 lines (i.e. hosts) so far...
# Processed 3200000 lines (i.e. hosts) so far...
# Processed 3210000 lines (i.e. hosts) so far...
# Processed 3220000 lines (i.e. hosts) so far...
# Processed 3230000 lines (i.e. hosts) so far...
# Processed 3240000 lines (i.e. hosts) so far...
# Processed 3250000 lines (i.e. hosts) so far...
# Processed 3260000 lines (i.e. hosts) so far...
# Processed 3270000 lines (i.e. hosts) so far...
# Processed 3280000 lines (i.e. hosts) so far...
# Processed 3290000 lines (i.e. hosts) so far...
# Processed 3300000 lines (i.e. hosts) so far...
# Processed 3310000 lines (i.e. hosts) so far...
# Processed 3320000 lines (i.e. hosts) so far...
# Processed 3330000 lines (i.e. hosts) so far...
# Processed 3340000 lines (i.e. hosts) so far...
# Processed 3350000 lines (i.e. hosts) so far...
# Processed 3360000 lines (i.e. hosts) so far...
# Processed 3370000 lines (i.e. hosts) so far...
# Processed 3380000 lines (i.e. hosts) so far...
# Processed 3390000 lines (i.e. hosts) so far...
# Processed 3400000 lines (i.e. hosts) so far...
# Processed 3410000 lines (i.e. hosts) so far...
# Processed 3420000 lines (i.e. hosts) so far...
# Processed 3430000 lines (i.e. hosts) so far...
# Processed 3440000 lines (i.e. hosts) so far...
# Processed 3450000 lines (i.e. hosts) so far...
# Processed 3460000 lines (i.e. hosts) so far...
# Processed 3470000 lines (i.e. hosts) so far...
# Processed 3480000 lines (i.e. hosts) so far...
# Processed 3490000 lines (i.e. hosts) so far...
# Processed 3500000 lines (i.e. hosts) so far...
# Processed 3510000 lines (i.e. hosts) so far...
# Processed 3520000 lines (i.e. hosts) so far...
# Processed 3530000 lines (i.e. hosts) so far...
# Processed 3540000 lines (i.e. hosts) so far...
# Processed 3550000 lines (i.e. hosts) so far...
# Processed 3560000 lines (i.e. hosts) so far...
# Processed 3570000 lines (i.e. hosts) so far...
# Processed 3580000 lines (i.e. hosts) so far...
# Processed 3590000 lines (i.e. hosts) so far...
# Processed 3600000 lines (i.e. hosts) so far...
# Processed 3610000 lines (i.e. hosts) so far...
# Processed 3620000 lines (i.e. hosts) so far...
# Processed 3630000 lines (i.e. hosts) so far...
# Processed 3640000 lines (i.e. hosts) so far...
# Processed 3650000 lines (i.e. hosts) so far...
# Processed 3660000 lines (i.e. hosts) so far...
# Processed 3670000 lines (i.e. hosts) so far...
# Processed 3680000 lines (i.e. hosts) so far...
# Processed 3690000 lines (i.e. hosts) so far...
# Processed 3700000 lines (i.e. hosts) so far...
# Processed 3710000 lines (i.e. hosts) so far...
# Processed 3720000 lines (i.e. hosts) so far...
# Processed 3730000 lines (i.e. hosts) so far...
# Processed 3740000 lines (i.e. hosts) so far...
# Processed 3750000 lines (i.e. hosts) so far...
# Processed 3760000 lines (i.e. hosts) so far...
# Processed 3770000 lines (i.e. hosts) so far...
# Processed 3780000 lines (i.e. hosts) so far...
# Processed 3790000 lines (i.e. hosts) so far...
# Processed 3800000 lines (i.e. hosts) so far...
# Processed 3810000 lines (i.e. hosts) so far...
# Processed 3820000 lines (i.e. hosts) so far...
# Processed 3830000 lines (i.e. hosts) so far...
# Processed 3840000 lines (i.e. hosts) so far...
# Processed 3850000 lines (i.e. hosts) so far...
# Processed 3860000 lines (i.e. hosts) so far...
# Processed 3870000 lines (i.e. hosts) so far...
# Processed 3880000 lines (i.e. hosts) so far...
# Processed 3890000 lines (i.e. hosts) so far...
# Processed 3900000 lines (i.e. hosts) so far...
# Processed 3910000 lines (i.e. hosts) so far...
# Processed 3920000 lines (i.e. hosts) so far...
# Processed 3930000 lines (i.e. hosts) so far...
# Processed 3940000 lines (i.e. hosts) so far...
# Processed 3950000 lines (i.e. hosts) so far...
# Processed 3960000 lines (i.e. hosts) so far...
# Processed 3970000 lines (i.e. hosts) so far...
# Processed 3980000 lines (i.e. hosts) so far...
# Processed 3990000 lines (i.e. hosts) so far...
# Processed 4000000 lines (i.e. hosts) so far...
# Processed 4010000 lines (i.e. hosts) so far...
# Processed 4020000 lines (i.e. hosts) so far...
# Processed 4030000 lines (i.e. hosts) so far...
# Processed 4040000 lines (i.e. hosts) so far...
# Processed 4050000 lines (i.e. hosts) so far...
# Processed 4060000 lines (i.e. hosts) so far...
# Processed 4070000 lines (i.e. hosts) so far...
# Processed 4080000 lines (i.e. hosts) so far...
# Processed 4090000 lines (i.e. hosts) so far...
# Processed 4100000 lines (i.e. hosts) so far...
# Processed 4110000 lines (i.e. hosts) so far...
# Processed 4120000 lines (i.e. hosts) so far...
# Processed 4130000 lines (i.e. hosts) so far...
# Processed 4140000 lines (i.e. hosts) so far...
# Processed 4150000 lines (i.e. hosts) so far...
# Processed 4160000 lines (i.e. hosts) so far...
# Processed 4170000 lines (i.e. hosts) so far...
# Processed 4180000 lines (i.e. hosts) so far...
# Processed 4190000 lines (i.e. hosts) so far...
# Processed 4200000 lines (i.e. hosts) so far...
# Processed 4210000 lines (i.e. hosts) so far...
# Processed 4220000 lines (i.e. hosts) so far...
# Processed 4230000 lines (i.e. hosts) so far...
# Processed 4240000 lines (i.e. hosts) so far...
# Processed 4250000 lines (i.e. hosts) so far...
# Processed 4260000 lines (i.e. hosts) so far...
# Processed 4270000 lines (i.e. hosts) so far...
# Processed 4280000 lines (i.e. hosts) so far...
# Processed 4290000 lines (i.e. hosts) so far...
# Processed 4300000 lines (i.e. hosts) so far...
# Processed 4310000 lines (i.e. hosts) so far...
# Processed 4320000 lines (i.e. hosts) so far...
# Processed 4330000 lines (i.e. hosts) so far...
# Processed 4340000 lines (i.e. hosts) so far...
# Processed 4350000 lines (i.e. hosts) so far...
# Processed 4360000 lines (i.e. hosts) so far...
# Processed 4370000 lines (i.e. hosts) so far...
# Processed 4380000 lines (i.e. hosts) so far...
# Processed 4390000 lines (i.e. hosts) so far...
# Processed 4400000 lines (i.e. hosts) so far...
# Processed 4410000 lines (i.e. hosts) so far...
# Processed 4420000 lines (i.e. hosts) so far...
# Processed 4430000 lines (i.e. hosts) so far...
# Processed 4440000 lines (i.e. hosts) so far...
# Processed 4450000 lines (i.e. hosts) so far...
# Processed 4460000 lines (i.e. hosts) so far...
# Processed 4470000 lines (i.e. hosts) so far...
# Processed 4480000 lines (i.e. hosts) so far...
# Processed 4490000 lines (i.e. hosts) so far...
# Processed 4500000 lines (i.e. hosts) so far...
# Processed 4510000 lines (i.e. hosts) so far...
# Processed 4520000 lines (i.e. hosts) so far...
# Processed 4530000 lines (i.e. hosts) so far...
# Processed 4540000 lines (i.e. hosts) so far...
# Processed 4550000 lines (i.e. hosts) so far...
# Processed 4560000 lines (i.e. hosts) so far...
# Processed 4570000 lines (i.e. hosts) so far...
# Processed 4580000 lines (i.e. hosts) so far...
# Processed 4590000 lines (i.e. hosts) so far...
# Processed 4600000 lines (i.e. hosts) so far...
# Processed 4610000 lines (i.e. hosts) so far...
# Processed 4620000 lines (i.e. hosts) so far...
# Processed 4630000 lines (i.e. hosts) so far...
# Processed 4640000 lines (i.e. hosts) so far...
# Processed 4650000 lines (i.e. hosts) so far...
# Processed 4660000 lines (i.e. hosts) so far...
# Processed 4670000 lines (i.e. hosts) so far...
# Processed 4680000 lines (i.e. hosts) so far...
# Processed 4690000 lines (i.e. hosts) so far...
# Processed 4700000 lines (i.e. hosts) so far...
# Processed 4710000 lines (i.e. hosts) so far...
# Processed 4720000 lines (i.e. hosts) so far...
# Processed 4730000 lines (i.e. hosts) so far...
# Processed 4740000 lines (i.e. hosts) so far...
# Processed 4750000 lines (i.e. hosts) so far...
# Processed 4760000 lines (i.e. hosts) so far...
# Processed 4770000 lines (i.e. hosts) so far...
# Processed 4780000 lines (i.e. hosts) so far...
# Processed 4790000 lines (i.e. hosts) so far...
# Processed 4800000 lines (i.e. hosts) so far...
# Processed 4810000 lines (i.e. hosts) so far...
# Processed 4820000 lines (i.e. hosts) so far...
# Processed 4830000 lines (i.e. hosts) so far...
# Processed 4840000 lines (i.e. hosts) so far...
# Processed 4850000 lines (i.e. hosts) so far...
# Processed 4860000 lines (i.e. hosts) so far...
# Processed 4870000 lines (i.e. hosts) so far...
# Processed 4880000 lines (i.e. hosts) so far...
# Processed 4890000 lines (i.e. hosts) so far...
# Processed 4900000 lines (i.e. hosts) so far...
# Processed 4910000 lines (i.e. hosts) so far...
# Processed 4920000 lines (i.e. hosts) so far...
# Processed 4930000 lines (i.e. hosts) so far...
# Processed 4940000 lines (i.e. hosts) so far...
# Processed 4950000 lines (i.e. hosts) so far...
# Processed 4960000 lines (i.e. hosts) so far...
# Processed 4970000 lines (i.e. hosts) so far...
# Processed 4980000 lines (i.e. hosts) so far...
# Processed 4990000 lines (i.e. hosts) so far...
# Processed 5000000 lines (i.e. hosts) so far...
# Processed 5010000 lines (i.e. hosts) so far...
# Processed 5020000 lines (i.e. hosts) so far...
# Processed 5030000 lines (i.e. hosts) so far...
# Processed 5040000 lines (i.e. hosts) so far...
# Processed 5050000 lines (i.e. hosts) so far...
# Processed 5060000 lines (i.e. hosts) so far...
# Processed 5070000 lines (i.e. hosts) so far...
# Processed 5080000 lines (i.e. hosts) so far...
# Processed 5090000 lines (i.e. hosts) so far...
# Processed 5100000 lines (i.e. hosts) so far...
# Processed 5110000 lines (i.e. hosts) so far...
# Processed 5120000 lines (i.e. hosts) so far...
# Processed 5130000 lines (i.e. hosts) so far...
# Processed 5140000 lines (i.e. hosts) so far...
# Processed 5150000 lines (i.e. hosts) so far...
# Processed 5160000 lines (i.e. hosts) so far...
# Processed 5170000 lines (i.e. hosts) so far...
# Processed 5180000 lines (i.e. hosts) so far...
# Processed 5190000 lines (i.e. hosts) so far...
# Processed 5200000 lines (i.e. hosts) so far...
# Processed 5210000 lines (i.e. hosts) so far...
# Processed 5220000 lines (i.e. hosts) so far...
# Processed 5230000 lines (i.e. hosts) so far...
# Processed 5240000 lines (i.e. hosts) so far...
# Processed 5250000 lines (i.e. hosts) so far...
# Processed 5260000 lines (i.e. hosts) so far...
# Processed 5270000 lines (i.e. hosts) so far...
# Processed 5280000 lines (i.e. hosts) so far...
# Processed 5290000 lines (i.e. hosts) so far...
# Processed 5300000 lines (i.e. hosts) so far...
# Processed 5310000 lines (i.e. hosts) so far...
# Processed 5320000 lines (i.e. hosts) so far...
# Processed 5330000 lines (i.e. hosts) so far...
# Processed 5340000 lines (i.e. hosts) so far...
# Processed 5350000 lines (i.e. hosts) so far...
# Processed 5360000 lines (i.e. hosts) so far...
# Processed 5370000 lines (i.e. hosts) so far...
# Processed 5380000 lines (i.e. hosts) so far...
# Processed 5390000 lines (i.e. hosts) so far...
# Processed 5400000 lines (i.e. hosts) so far...
# Processed 5410000 lines (i.e. hosts) so far...
# Processed 5420000 lines (i.e. hosts) so far...
# Processed 5430000 lines (i.e. hosts) so far...
# Processed 5440000 lines (i.e. hosts) so far...
# Processed 5450000 lines (i.e. hosts) so far...
# Processed 5460000 lines (i.e. hosts) so far...
# Processed 5470000 lines (i.e. hosts) so far...
# Processed 5480000 lines (i.e. hosts) so far...
# Processed 5490000 lines (i.e. hosts) so far...
# Processed 5500000 lines (i.e. hosts) so far...
# Processed 5510000 lines (i.e. hosts) so far...
# Processed 5520000 lines (i.e. hosts) so far...
# Processed 5530000 lines (i.e. hosts) so far...
# Processed 5540000 lines (i.e. hosts) so far...
# Processed 5550000 lines (i.e. hosts) so far...
# Processed 5560000 lines (i.e. hosts) so far...
# Processed 5570000 lines (i.e. hosts) so far...
# Processed 5580000 lines (i.e. hosts) so far...
# Processed 5590000 lines (i.e. hosts) so far...
# Processed 5600000 lines (i.e. hosts) so far...
# Processed 5610000 lines (i.e. hosts) so far...
# Processed 5620000 lines (i.e. hosts) so far...
# Processed 5630000 lines (i.e. hosts) so far...
# Processed 5640000 lines (i.e. hosts) so far...
# Processed 5650000 lines (i.e. hosts) so far...
# Processed 5660000 lines (i.e. hosts) so far...
# Processed 5670000 lines (i.e. hosts) so far...
# Processed 5680000 lines (i.e. hosts) so far...
# Processed 5690000 lines (i.e. hosts) so far...
# Processed 5700000 lines (i.e. hosts) so far...
# Processed 5710000 lines (i.e. hosts) so far...
# Processed 5720000 lines (i.e. hosts) so far...
# Processed 5730000 lines (i.e. hosts) so far...
# Processed 5740000 lines (i.e. hosts) so far...
# Processed 5750000 lines (i.e. hosts) so far...
# Processed 5760000 lines (i.e. hosts) so far...
# Processed 5770000 lines (i.e. hosts) so far...
# Processed 5780000 lines (i.e. hosts) so far...
# Processed 5790000 lines (i.e. hosts) so far...
# Processed 5800000 lines (i.e. hosts) so far...
# Processed 5810000 lines (i.e. hosts) so far...
# Processed 5820000 lines (i.e. hosts) so far...
# Processed 5830000 lines (i.e. hosts) so far...
# Processed 5840000 lines (i.e. hosts) so far...
# Processed 5850000 lines (i.e. hosts) so far...
# Processed 5860000 lines (i.e. hosts) so far...
# Processed 5870000 lines (i.e. hosts) so far...
# Processed 5880000 lines (i.e. hosts) so far...
# Processed 5890000 lines (i.e. hosts) so far...
# Processed 5900000 lines (i.e. hosts) so far...
# Processed 5910000 lines (i.e. hosts) so far...
# Processed 5920000 lines (i.e. hosts) so far...
# Processed 5930000 lines (i.e. hosts) so far...
# Processed 5940000 lines (i.e. hosts) so far...
# Processed 5950000 lines (i.e. hosts) so far...
# Processed 5960000 lines (i.e. hosts) so far...
# Processed 5970000 lines (i.e. hosts) so far...
# Processed 5980000 lines (i.e. hosts) so far...
# Processed 5990000 lines (i.e. hosts) so far...
# Processed 6000000 lines (i.e. hosts) so far...
# Processed 6010000 lines (i.e. hosts) so far...
# Processed 6020000 lines (i.e. hosts) so far...
# Processed 6030000 lines (i.e. hosts) so far...
# Processed 6040000 lines (i.e. hosts) so far...
# Processed 6050000 lines (i.e. hosts) so far...
# Processed 6060000 lines (i.e. hosts) so far...
# Processed 6070000 lines (i.e. hosts) so far...
# Processed 6080000 lines (i.e. hosts) so far...
# Processed 6090000 lines (i.e. hosts) so far...
# Processed 6100000 lines (i.e. hosts) so far...
# Processed 6110000 lines (i.e. hosts) so far...
# Processed 6120000 lines (i.e. hosts) so far...
# Processed 6130000 lines (i.e. hosts) so far...
# Processed 6140000 lines (i.e. hosts) so far...
# Processed 6150000 lines (i.e. hosts) so far...
# Processed 6160000 lines (i.e. hosts) so far...
# Processed 6170000 lines (i.e. hosts) so far...
# Processed 6180000 lines (i.e. hosts) so far...
# Processed 6190000 lines (i.e. hosts) so far...
# Processed 6200000 lines (i.e. hosts) so far...
# Processed 6210000 lines (i.e. hosts) so far...
# Processed 6220000 lines (i.e. hosts) so far...
# Processed 6230000 lines (i.e. hosts) so far...
# Processed 6240000 lines (i.e. hosts) so far...
# Processed 6250000 lines (i.e. hosts) so far...
# Processed 6260000 lines (i.e. hosts) so far...
# Processed 6270000 lines (i.e. hosts) so far...
# Processed 6280000 lines (i.e. hosts) so far...
# Processed 6290000 lines (i.e. hosts) so far...
# Processed 6300000 lines (i.e. hosts) so far...
# Processed 6310000 lines (i.e. hosts) so far...
# Processed 6320000 lines (i.e. hosts) so far...
# Processed 6330000 lines (i.e. hosts) so far...
# Processed 6340000 lines (i.e. hosts) so far...
# Processed 6350000 lines (i.e. hosts) so far...
# Processed 6360000 lines (i.e. hosts) so far...
# Processed 6370000 lines (i.e. hosts) so far...
# Processed 6380000 lines (i.e. hosts) so far...
# Processed 6390000 lines (i.e. hosts) so far...
# Processed 6400000 lines (i.e. hosts) so far...
# Processed 6410000 lines (i.e. hosts) so far...
# Processed 6420000 lines (i.e. hosts) so far...
# Processed 6430000 lines (i.e. hosts) so far...
# Processed 6440000 lines (i.e. hosts) so far...
# Processed 6450000 lines (i.e. hosts) so far...
# Processed 6460000 lines (i.e. hosts) so far...
# Processed 6470000 lines (i.e. hosts) so far...
# Processed 6480000 lines (i.e. hosts) so far...
# Processed 6490000 lines (i.e. hosts) so far...
# Processed 6500000 lines (i.e. hosts) so far...
# Processed 6510000 lines (i.e. hosts) so far...
# Processed 6520000 lines (i.e. hosts) so far...
# Processed 6530000 lines (i.e. hosts) so far...
# Processed 6540000 lines (i.e. hosts) so far...
# Processed 6550000 lines (i.e. hosts) so far...
# Processed 6560000 lines (i.e. hosts) so far...
# Processed 6570000 lines (i.e. hosts) so far...
# Processed 6580000 lines (i.e. hosts) so far...
# Processed 6590000 lines (i.e. hosts) so far...
# Processed 6600000 lines (i.e. hosts) so far...
# Processed 6610000 lines (i.e. hosts) so far...
# Processed 6620000 lines (i.e. hosts) so far...
# Processed 6630000 lines (i.e. hosts) so far...
# Processed 6640000 lines (i.e. hosts) so far...
# Processed 6650000 lines (i.e. hosts) so far...
# Processed 6660000 lines (i.e. hosts) so far...
# Processed 6670000 lines (i.e. hosts) so far...
# Processed 6680000 lines (i.e. hosts) so far...
# Processed 6690000 lines (i.e. hosts) so far...
# Processed 6700000 lines (i.e. hosts) so far...
# Processed 6710000 lines (i.e. hosts) so far...
# Processed 6720000 lines (i.e. hosts) so far...
# Processed 6730000 lines (i.e. hosts) so far...
# Processed 6740000 lines (i.e. hosts) so far...
# Processed 6750000 lines (i.e. hosts) so far...
# Processed 6760000 lines (i.e. hosts) so far...
# Processed 6770000 lines (i.e. hosts) so far...
# Processed 6780000 lines (i.e. hosts) so far...
# Processed 6790000 lines (i.e. hosts) so far...
# Processed 6800000 lines (i.e. hosts) so far...
# Processed 6810000 lines (i.e. hosts) so far...
# Processed 6820000 lines (i.e. hosts) so far...
# Processed 6830000 lines (i.e. hosts) so far...
# Processed 6840000 lines (i.e. hosts) so far...
# Processed 6850000 lines (i.e. hosts) so far...
# Processed 6860000 lines (i.e. hosts) so far...
# Processed 6870000 lines (i.e. hosts) so far...
# Processed 6880000 lines (i.e. hosts) so far...
# Processed 6890000 lines (i.e. hosts) so far...
# Processed 6900000 lines (i.e. hosts) so far...
# Processed 6910000 lines (i.e. hosts) so far...
# Processed 6920000 lines (i.e. hosts) so far...
# Processed 6930000 lines (i.e. hosts) so far...
# Processed 6940000 lines (i.e. hosts) so far...
# Processed 6950000 lines (i.e. hosts) so far...
# Processed 6960000 lines (i.e. hosts) so far...
# Processed 6970000 lines (i.e. hosts) so far...
# Processed 6980000 lines (i.e. hosts) so far...
# Processed 6990000 lines (i.e. hosts) so far...
# Processed 7000000 lines (i.e. hosts) so far...
# Processed 7010000 lines (i.e. hosts) so far...
# Processed 7020000 lines (i.e. hosts) so far...
# Processed 7030000 lines (i.e. hosts) so far...
# Processed 7040000 lines (i.e. hosts) so far...
# Processed 7050000 lines (i.e. hosts) so far...
# Processed 7060000 lines (i.e. hosts) so far...
# Processed 7070000 lines (i.e. hosts) so far...
# Processed 7080000 lines (i.e. hosts) so far...
# Processed 7090000 lines (i.e. hosts) so far...
# Processed 7100000 lines (i.e. hosts) so far...
# Processed 7110000 lines (i.e. hosts) so far...
# Processed 7120000 lines (i.e. hosts) so far...
# Processed 7130000 lines (i.e. hosts) so far...
# Processed 7140000 lines (i.e. hosts) so far...
# Processed 7150000 lines (i.e. hosts) so far...
# Processed 7160000 lines (i.e. hosts) so far...
# Processed 7170000 lines (i.e. hosts) so far...
# Processed 7180000 lines (i.e. hosts) so far...
# Processed 7190000 lines (i.e. hosts) so far...
# Processed 7200000 lines (i.e. hosts) so far...
# Processed 7210000 lines (i.e. hosts) so far...
# Processed 7220000 lines (i.e. hosts) so far...
# Processed 7230000 lines (i.e. hosts) so far...
# Processed 7240000 lines (i.e. hosts) so far...
# Processed 7250000 lines (i.e. hosts) so far...
# Processed 7260000 lines (i.e. hosts) so far...
# Processed 7270000 lines (i.e. hosts) so far...
# Processed 7280000 lines (i.e. hosts) so far...
# Processed 7290000 lines (i.e. hosts) so far...
# Processed 7300000 lines (i.e. hosts) so far...
# Processed 7310000 lines (i.e. hosts) so far...
# Processed 7320000 lines (i.e. hosts) so far...
# Processed 7330000 lines (i.e. hosts) so far...
# Processed 7340000 lines (i.e. hosts) so far...
# Processed 7350000 lines (i.e. hosts) so far...
# Processed 7360000 lines (i.e. hosts) so far...
# Processed 7370000 lines (i.e. hosts) so far...
# Processed 7380000 lines (i.e. hosts) so far...
# Processed 7390000 lines (i.e. hosts) so far...
# Processed 7400000 lines (i.e. hosts) so far...
# Processed 7410000 lines (i.e. hosts) so far...
# Processed 7420000 lines (i.e. hosts) so far...
# Processed 7430000 lines (i.e. hosts) so far...
# Processed 7440000 lines (i.e. hosts) so far...
# Processed 7450000 lines (i.e. hosts) so far...
# Processed 7460000 lines (i.e. hosts) so far...
# Processed 7470000 lines (i.e. hosts) so far...
# Processed 7480000 lines (i.e. hosts) so far...
# Processed 7490000 lines (i.e. hosts) so far...
# Processed 7500000 lines (i.e. hosts) so far...
# Processed 7510000 lines (i.e. hosts) so far...
# Processed 7520000 lines (i.e. hosts) so far...
# Processed 7530000 lines (i.e. hosts) so far...
# Processed 7540000 lines (i.e. hosts) so far...
# Processed 7550000 lines (i.e. hosts) so far...
# Processed 7560000 lines (i.e. hosts) so far...
# Processed 7570000 lines (i.e. hosts) so far...
# Processed 7580000 lines (i.e. hosts) so far...
# Processed 7590000 lines (i.e. hosts) so far...
# Processed 7600000 lines (i.e. hosts) so far...
# Processed 7610000 lines (i.e. hosts) so far...
# Processed 7620000 lines (i.e. hosts) so far...
# Processed 7630000 lines (i.e. hosts) so far...
# Processed 7640000 lines (i.e. hosts) so far...
# Processed 7650000 lines (i.e. hosts) so far...
# Processed 7660000 lines (i.e. hosts) so far...
# Processed 7670000 lines (i.e. hosts) so far...
# Processed 7680000 lines (i.e. hosts) so far...
# Processed 7690000 lines (i.e. hosts) so far...
# Processed 7700000 lines (i.e. hosts) so far...
# Processed 7710000 lines (i.e. hosts) so far...
# Processed 7720000 lines (i.e. hosts) so far...
# Processed 7730000 lines (i.e. hosts) so far...
# Processed 7740000 lines (i.e. hosts) so far...
# Processed 7750000 lines (i.e. hosts) so far...
# Processed 7760000 lines (i.e. hosts) so far...
# Processed 7770000 lines (i.e. hosts) so far...
# Processed 7780000 lines (i.e. hosts) so far...
# Processed 7790000 lines (i.e. hosts) so far...
# Processed 7800000 lines (i.e. hosts) so far...
# Processed 7810000 lines (i.e. hosts) so far...
# Processed 7820000 lines (i.e. hosts) so far...
# Processed 7830000 lines (i.e. hosts) so far...
# Processed 7840000 lines (i.e. hosts) so far...
# Processed 7850000 lines (i.e. hosts) so far...
# Processed 7860000 lines (i.e. hosts) so far...
# Processed 7870000 lines (i.e. hosts) so far...
# Processed 7880000 lines (i.e. hosts) so far...
# Processed 7890000 lines (i.e. hosts) so far...
# Processed 7900000 lines (i.e. hosts) so far...
# Processed 7910000 lines (i.e. hosts) so far...
# Processed 7920000 lines (i.e. hosts) so far...
# Processed 7930000 lines (i.e. hosts) so far...
# Processed 7940000 lines (i.e. hosts) so far...
# Processed 7950000 lines (i.e. hosts) so far...
# Processed 7960000 lines (i.e. hosts) so far...
# Processed 7970000 lines (i.e. hosts) so far...
# Processed 7980000 lines (i.e. hosts) so far...
# Processed 7990000 lines (i.e. hosts) so far...
# Processed 8000000 lines (i.e. hosts) so far...
# Processed 8010000 lines (i.e. hosts) so far...
# Processed 8020000 lines (i.e. hosts) so far...
# Processed 8030000 lines (i.e. hosts) so far...
# Processed 8040000 lines (i.e. hosts) so far...
# Processed 8050000 lines (i.e. hosts) so far...
# Processed 8060000 lines (i.e. hosts) so far...
# Processed 8070000 lines (i.e. hosts) so far...
# Processed 8080000 lines (i.e. hosts) so far...
# Processed 8090000 lines (i.e. hosts) so far...
# Processed 8100000 lines (i.e. hosts) so far...
# Processed 8110000 lines (i.e. hosts) so far...
# Processed 8120000 lines (i.e. hosts) so far...
# Processed 8130000 lines (i.e. hosts) so far...
# Processed 8140000 lines (i.e. hosts) so far...
# Processed 8150000 lines (i.e. hosts) so far...
# Processed 8160000 lines (i.e. hosts) so far...
# Processed 8170000 lines (i.e. hosts) so far...
# Processed 8180000 lines (i.e. hosts) so far...
# Processed 8190000 lines (i.e. hosts) so far...
# Processed 8200000 lines (i.e. hosts) so far...
# Processed 8210000 lines (i.e. hosts) so far...
# Processed 8220000 lines (i.e. hosts) so far...
# Processed 8230000 lines (i.e. hosts) so far...
# Processed 8240000 lines (i.e. hosts) so far...
# Processed 8250000 lines (i.e. hosts) so far...
# Processed 8260000 lines (i.e. hosts) so far...
# Processed 8270000 lines (i.e. hosts) so far...
# Processed 8280000 lines (i.e. hosts) so far...
# Processed 8290000 lines (i.e. hosts) so far...
# Processed 8300000 lines (i.e. hosts) so far...
# Processed 8310000 lines (i.e. hosts) so far...
# Processed 8320000 lines (i.e. hosts) so far...
# Processed 8330000 lines (i.e. hosts) so far...
# Processed 8340000 lines (i.e. hosts) so far...
# Processed 8350000 lines (i.e. hosts) so far...
# Processed 8360000 lines (i.e. hosts) so far...
# Processed 8370000 lines (i.e. hosts) so far...
# Processed 8380000 lines (i.e. hosts) so far...
# Processed 8390000 lines (i.e. hosts) so far...
# Processed 8400000 lines (i.e. hosts) so far...
# Processed 8410000 lines (i.e. hosts) so far...
# Processed 8420000 lines (i.e. hosts) so far...
# Processed 8430000 lines (i.e. hosts) so far...
# Processed 8440000 lines (i.e. hosts) so far...
# Processed 8450000 lines (i.e. hosts) so far...
# Processed 8460000 lines (i.e. hosts) so far...
# Processed 8470000 lines (i.e. hosts) so far...
# Processed 8480000 lines (i.e. hosts) so far...
# Processed 8490000 lines (i.e. hosts) so far...
# Processed 8500000 lines (i.e. hosts) so far...
# Processed 8510000 lines (i.e. hosts) so far...
# Processed 8520000 lines (i.e. hosts) so far...
# Processed 8530000 lines (i.e. hosts) so far...
# Processed 8540000 lines (i.e. hosts) so far...
# Processed 8550000 lines (i.e. hosts) so far...
# Processed 8560000 lines (i.e. hosts) so far...
# Processed 8570000 lines (i.e. hosts) so far...
# Processed 8580000 lines (i.e. hosts) so far...
# Processed 8590000 lines (i.e. hosts) so far...
# Processed 8600000 lines (i.e. hosts) so far...
# Processed 8610000 lines (i.e. hosts) so far...
# Processed 8620000 lines (i.e. hosts) so far...
# Processed 8630000 lines (i.e. hosts) so far...
# Processed 8640000 lines (i.e. hosts) so far...
# Processed 8650000 lines (i.e. hosts) so far...
# Processed 8660000 lines (i.e. hosts) so far...
# Processed 8670000 lines (i.e. hosts) so far...
# Processed 8680000 lines (i.e. hosts) so far...
# Processed 8690000 lines (i.e. hosts) so far...
# Processed 8700000 lines (i.e. hosts) so far...
# Processed 8710000 lines (i.e. hosts) so far...
# Processed 8720000 lines (i.e. hosts) so far...
# Processed 8730000 lines (i.e. hosts) so far...
# Processed 8740000 lines (i.e. hosts) so far...
# Processed 8750000 lines (i.e. hosts) so far...
# Processed 8760000 lines (i.e. hosts) so far...
# Processed 8770000 lines (i.e. hosts) so far...
# Processed 8780000 lines (i.e. hosts) so far...
# Processed 8790000 lines (i.e. hosts) so far...
# Processed 8800000 lines (i.e. hosts) so far...
# Processed 8810000 lines (i.e. hosts) so far...
# Processed 8820000 lines (i.e. hosts) so far...
# Processed 8830000 lines (i.e. hosts) so far...
# Processed 8840000 lines (i.e. hosts) so far...
# Processed 8850000 lines (i.e. hosts) so far...
# Processed 8860000 lines (i.e. hosts) so far...
# Processed 8870000 lines (i.e. hosts) so far...
# Processed 8880000 lines (i.e. hosts) so far...
# Processed 8890000 lines (i.e. hosts) so far...
# Processed 8900000 lines (i.e. hosts) so far...
# Processed 8910000 lines (i.e. hosts) so far...
# Processed 8920000 lines (i.e. hosts) so far...
# Processed 8930000 lines (i.e. hosts) so far...
# Processed 8940000 lines (i.e. hosts) so far...
# Processed 8950000 lines (i.e. hosts) so far...
# Processed 8960000 lines (i.e. hosts) so far...
# Processed 8970000 lines (i.e. hosts) so far...
# Processed 8980000 lines (i.e. hosts) so far...
# Processed 8990000 lines (i.e. hosts) so far...
# Processed 9000000 lines (i.e. hosts) so far...
# Processed 9010000 lines (i.e. hosts) so far...
# Processed 9020000 lines (i.e. hosts) so far...
# Processed 9030000 lines (i.e. hosts) so far...
# Processed 9040000 lines (i.e. hosts) so far...
# Processed 9050000 lines (i.e. hosts) so far...
# Processed 9060000 lines (i.e. hosts) so far...
# Processed 9070000 lines (i.e. hosts) so far...
# Processed 9080000 lines (i.e. hosts) so far...
# Processed 9090000 lines (i.e. hosts) so far...
# Processed 9100000 lines (i.e. hosts) so far...
# Processed 9110000 lines (i.e. hosts) so far...
# Processed 9120000 lines (i.e. hosts) so far...
# Processed 9130000 lines (i.e. hosts) so far...
# Processed 9140000 lines (i.e. hosts) so far...
# Processed 9150000 lines (i.e. hosts) so far...
# Processed 9160000 lines (i.e. hosts) so far...
# Processed 9170000 lines (i.e. hosts) so far...
# Processed 9180000 lines (i.e. hosts) so far...
# Processed 9190000 lines (i.e. hosts) so far...
# Processed 9200000 lines (i.e. hosts) so far...
# Processed 9210000 lines (i.e. hosts) so far...
# Processed 9220000 lines (i.e. hosts) so far...
# Processed 9230000 lines (i.e. hosts) so far...
# Processed 9240000 lines (i.e. hosts) so far...
# Processed 9250000 lines (i.e. hosts) so far...
# Loaded data from 9255383 lines/hosts.
# Loaded.

# %% [markdown]
# ## % .uk domain and non-uk

# %%
for tld, count in tlds.items():
    if ":" in tld:
        val = tlds.pop(tld)
        tlds[tld.split(":")[0]] += val

tld_labels = list(tlds.keys())
tld_total = sum(list(tlds.values()))
tld_fractions = [float(value)/float(tld_total) for value in tlds.values()]
tld_explode = [1 for l in tld_labels]

tlds_sorted = OrderedDict(sorted(tlds.items(), key=lambda x: x[1], reverse=True))

#plt.axis("equal")
#plt.pie(tld_fractions, labels=tld_labels, shadow=False, explode=tld_explode, autopct="%1.1f%%")

fig = plt.figure(figsize=(16,6))

# Plot up to 15
tldc = 10
if(len(tlds_sorted) < tldc):
    tldc = len(tlds_sorted)

seaborn.set_style("darkgrid")
seaborn.barplot(range(tldc), tlds_sorted.values()[:tldc])

plt.xticks(range(tldc), tlds_sorted.keys()[:tldc])
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
fewer_values = tlds_sorted.values()[0:tldc]
fewer_keys = tlds_sorted.keys()[0:tldc]
plt.pie(fewer_values, colors=colors, startangle=90, autopct='%1.1f%%')
plt.legend(fewer_keys, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# The above shows that things are very heavily skewed to `.uk` and `.com`. We can switch to a logarithmic scale to make things a bit clearer:

# %%
fig = plt.figure(figsize=(16,6))

seaborn.barplot(range(tldc), tlds_sorted.values()[:tldc])

plt.xticks(range(tldc), tlds_sorted.keys()[:tldc])
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Type of second level domain – so what % .co.uk, .org.uk , .ac.uk etc

# %%
slds_sorted = OrderedDict(sorted(slds.items(), key=lambda x: x[1], reverse=True))

print(slds_sorted)

fig = plt.figure(figsize=(16,6))

seaborn.barplot(range(len(slds_sorted)), slds_sorted.values())

plt.xticks(range(len(slds_sorted)), slds_sorted.keys())
plt.yscale('log')
plt.show()
# Out:
# OrderedDict([(u'co', 7136188), (u'org', 399506), (u'me', 105225), (u'ac', 37184), (u'sch', 18728), (u'gov', 10952), (u'nhs', 5638), (u'ltd', 5501), (u'net', 928), (u'plc', 331), (u'mod', 164), (u'parliament', 53), (u'nic', 29)])

# %% [markdown]
# ## Geolocation

# %%
lat_y = [lat for lat, lon in lat_lon if lat is not None]
lon_x = [lon for lat, lon in lat_lon if lon is not None]

# Reset the plot colours for the map plots:
seaborn.set(rc={'axes.facecolor':'none', 'figure.facecolor':'none'})

fig = plt.figure(figsize=(20,16))

m = Basemap(projection='mill',lon_0=0)
#m = Basemap(llcrnrlon=-8.0,llcrnrlat=54.5,urcrnrlon=1.5,urcrnrlat=59.5,lat_ts=20,
#            resolution='h',projection='merc',lon_0=-4.36,lat_0=54.5)

#m.drawcoastlines(color='gray')
#m.drawcountries(color='gray')
m.fillcontinents(color='lightgrey')
#m.drawmapboundary(fill_color='white') # fill to edge
#m.drawparallels(np.arange(-90.,120.,30.),labels=[1,0,0,0]) # draw parallels
#m.drawmeridians(np.arange(0.,420.,60.),labels=[0,0,0,1]) # draw meridians

x1,y1=m(lon_x,lat_y)
#m.scatter(x1,y1,s=5,c='r',marker="o",cmap=cm.jet,alpha=1.0)
m.plot(x1,y1, 'r.', markersize=5, alpha=0.5)


plt.savefig('2015-ldwa-map.png', bbox_inches='tight', dpi=150)
plt.savefig('2015-ldwa-map.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# The above graph can be downloaded in [PNG](./2015-ldwa-map.png) or [PDF](./2015-ldwa-map.pdf) formats.

# %%
# Set up a UK bounding box:
bbox = {
  'lon': -5.23636,
  'lat': 53.866772,
  'll_lon': -10.65073,
  'll_lat': 49.16209,
  'ur_lon': 1.76334,
  'ur_lat': 60.860699
}

# Reset the plot colours for the map plots:
seaborn.set(rc={'axes.facecolor':'none', 'figure.facecolor':'none'})

fig = plt.figure(figsize=(20,16))

m = Basemap(
  projection='mill', lon_0=bbox['lon'], lat_0=bbox['lat'],
  llcrnrlon=bbox['ll_lon'], llcrnrlat=bbox['ll_lat'],
  urcrnrlon=bbox['ur_lon'], urcrnrlat=bbox['ur_lat'], resolution='h')

#m.drawcoastlines(color='gray')
#m.drawcountries(color='gray')
m.fillcontinents(color='lightgrey')

x1,y1=m(lon_x,lat_y)
#m.scatter(x1,y1,s=5,c='r',marker="o",cmap=cm.jet,alpha=1.0)
m.plot(x1,y1, 'r.', markersize=10, alpha=0.5)

plt.savefig('2015-ldwa-uk-map.png', bbox_inches='tight', dpi=150)
plt.savefig('2015-ldwa-uk-map.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# The above graph can be downloaded in [PNG](./2015-ldwa-uk-map.png) or [PDF](./2015-ldwa-uk-map.pdf) formats.

# %%
# Reset the plot colours for the map plots:
seaborn.set(rc={'axes.facecolor':'none', 'figure.facecolor':'none'})

fig = plt.figure(figsize=(14,14))

# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
map = Basemap(projection='ortho', lat_0=30, lon_0=0,
              resolution='l', area_thresh=1000.0)
 
#map.drawcoastlines(color='gray', linewidth=0.25)
#map.drawcountries(linewidth=0.25)
map.fillcontinents(color='lightgrey',lake_color='white')
# draw the edge of the map projection region (the projection limb)
#map.drawmapboundary(fill_color='aqua')

x,y = map(lon_x,lat_y)
map.plot(x, y, 'r.', markersize=5, alpha=0.5)

plt.savefig('2015-ldwa-globe-map.png', bbox_inches='tight', dpi=150)
plt.savefig('2015-ldwa-globe-map.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# The above graph can be downloaded in [PNG](./2015-ldwa-globe-map.png) or [PDF](./2015-ldwa-globe-map.pdf) formats.

# %% [markdown]
# ## Largest sites in terms of no. of pages.

# %%
hosts_by_size = sorted(host_sizes.items(), key=lambda x:x[1])[-20:]
hosts_by_size.reverse()
print "\n".join([host for (host, size) in hosts_by_size])
# Out:
# i-grasp.com
# clikpic.com
# hants.gov.uk
# open.ac.uk
# tate.org.uk
# plymouth.ac.uk
# alcoholics-anonymous.org.uk
# streetmap.co.uk
# lakelandwildlife.co.uk
# selfsufficientish.com
# alibris-static.com
# chaplins.co.uk
# rgu.ac.uk
# rbht.nhs.uk
# iaw.org.uk
# arlsupportservices.co.uk
# hctgroup.org
# ancestorstree.co.uk
# gaynors-goodies.co.uk
# warwickcanoe.co.uk

# %% [markdown]
# It's not clear how meaningful the above list is. Those sites with many resources may just be link farms or other search-engine spamming attempts.
